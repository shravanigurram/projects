# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/project_daup/creditcard_2023.csv')
data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class_distribution = data['Class'].value_counts()  # Replace 'Class' with your target variable column name
print("Class Distribution:")
print(class_distribution)
# Out:
# Class Distribution:
# Class
# 0    284315
# 1    284315
# Name: count, dtype: int64

# %%
class_percentage = data['Class'].value_counts(normalize=True) * 100
print("\nClass Percentage Distribution:")
print(class_percentage)
# Out:
# Class Percentage Distribution:
# Class
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %%
print(f"Dataset contains {data.shape[0]} rows and {data.shape[1]} columns.")
# Out:
# Dataset contains 568630 rows and 31 columns.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
# Display summary statistics for numerical columns
data.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17
# std    164149.486121  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   7.997245e-18 -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17
# ...

# %%
# Check for missing values in each column
data.isnull().sum()
# Out:
# id        0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
print(data["Class"].value_counts(normalize=True) * 100)
# Out:
# Class
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
numerical_cols = data.select_dtypes(include=['number']).columns.tolist()
print(numerical_cols)
# Out:
# ['id', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class']

# %% [markdown]
# **Distribution of numerical columns**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'data' is your Pandas DataFrame and 'numerical_cols' is the list of numerical columns
for col in numerical_cols:
    plt.figure(figsize=(8, 6))
    sns.histplot(data[col], kde=True)
    plt.title(f'Distribution of {col}')  # Set title
    plt.xlabel(col)  # Set x-axis label
    plt.ylabel('Frequency')  # Set y-axis label
    plt.show()  # Display the plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Calculate the correlation matrix
correlation_matrix = data[numerical_cols].corr()
# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", vmin=-1, vmax=1)
plt.title("Correlation Heatmap of Numerical Features")
plt.show()

# %% [markdown]
# **Box Plot**

# %%
# Plot box plots for each numerical feature to detect outliers
import matplotlib.pyplot as plt
import seaborn as sns
import math

# Calculate the number of rows and columns for subplots
num_cols = len(numerical_cols)
num_rows = math.ceil(num_cols / 3)  # Calculate rows to accommodate all columns

plt.figure(figsize=(20,30))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(num_rows, 3, i)  # Adjust subplot grid dynamically
    sns.boxplot(y=data[col], color="skyblue")
    plt.title(f"Outliers in {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# **removes outliers from a DataFrame.**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from sklearn.preprocessing import RobustScaler
from imblearn.over_sampling import SMOTE

def remove_outliers_limited(data, numerical_cols, threshold=1.5, min_samples=5):
    """
    Removes outliers using IQR but ensures no class is entirely removed.

    Args:
        data: Pandas DataFrame.
        numerical_cols: List of numerical columns for outlier removal.
        threshold: Multiplier for IQR to define outlier bounds (default: 1.5).
        min_samples: Minimum number of samples per class to keep.

    Returns:
        Pandas DataFrame with outliers removed while preserving all classes.
    """
    data_clean = data.copy()

    for col in numerical_cols:
        Q1 = data_clean[col].quantile(0.25)
        Q3 = data_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - threshold * IQR
        upper_bound = Q3 + threshold * IQR

        # Remove outliers but ensure each class has at least 'min_samples'
        outliers = (data_clean[col] < lower_bound) | (data_clean[col] > upper_bound)
        temp_data = data_clean[~outliers]

        # Check class distribution
        class_counts = temp_data['Class'].value_counts()
        if (class_counts >= min_samples).all():
            data_clean = temp_data  # Apply changes only if all classes have enough samples

    return data_clean

# Apply outlier removal with class preservation
filtered_data = remove_outliers_limited(data, numerical_cols)

# Plot boxplots AFTER outlier removal
num_cols = len(numerical_cols)
num_rows = math.ceil(num_cols / 3)

plt.figure(figsize=(20, 40))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(num_rows, 3, i)
    sns.boxplot(y=filtered_data[col], color="skyblue")
    plt.title(f"Outliers in {col} (After Controlled Removal)")

plt.tight_layout()
plt.show()

# If class imbalance exists after outlier removal, apply SMOTE to balance classes
X = filtered_data.drop(columns=['Class'])
y = filtered_data['Class']

smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Convert back to DataFrame
balanced_data = pd.DataFrame(X_resampled, columns=X.columns)
balanced_data['Class'] = y_resampled

print("Final Data Class Distribution:")
print(balanced_data['Class'].value_counts())
# Out:
# Final Data Class Distribution:
# Class
# 0    181062
# 1    181062
# Name: count, dtype: int64

# %%
filtered_data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
# 5   5  0.025302 -0.140514  1.191138 -0.707979  0.430490  0.458973  0.611050
# 6   6  1.016482 -0.397181  0.497868 -0.144463  0.331022  0.629243  0.431262
# 9   9  0.058419 -0.093507  1.117270 -0.735172  0.466111  0.332371  0.683425
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
# 5 -0.092629  0.180811  ... -0.187739 -0.538518 -0.050465 -0.631553 -0.456480
# 6 -0.134007  0.796159  ... -0.171137 -0.287017 -0.178197 -1.297597  1.182503
# 9 -0.136674  0.096409  ... -0.203634 -0.601581 -0.145082 -0.654783 -0.196621
#
# ...

# %%
import pandas as pd
import scipy.stats as stats
skewness = filtered_data.skew()
print("Skewness:")
print(skewness)
# Out:
# Skewness:
# id        0.630718
# V1        0.310192
# V2       -0.004318
# V3        0.441611
# V4       -0.086167
# V5        0.426425
# V6       -0.145785
# V7       -0.180370
# V8        0.864215
# V9        0.180306
# V10      -0.356741
# V11      -0.237125
# V12      -0.177823
# V13      -0.019559
# V14      -0.475409
# V15       0.071470
# V16       0.156905
# V17      -0.747243
# V18       0.258769
# V19      -0.121399
# V20       0.442797
# V21       0.502946
# V22       0.234550
# V23       0.177195
# V24      -0.168138
# V25      -0.156590
# V26       0.171358
# V27       0.913479
# V28       0.500897
# Amount    0.006178
# Class     1.072085
# dtype: float64

# %% [markdown]
# **kurtosis**

# %%
kurtosis = filtered_data.kurtosis()


print("\nKurtosis:")
print(kurtosis)
# Out:
# Kurtosis:
# id       -0.538448
# V1       -1.206903
# V2        0.507466
# V3       -0.135217
# V4        0.337558
# V5        0.184995
# V6        0.907397
# V7        0.024075
# V8        1.219095
# V9       -0.005976
# V10       0.264379
# V11      -0.404192
# V12      -0.392663
# V13      -0.397099
# V14       0.446447
# V15      -0.372463
# V16       0.179855
# V17       1.107102
# V18       0.007890
# V19       0.133055
# V20       0.423024
# V21       0.126130
# V22      -0.459736
# V23       0.051596
# V24      -0.141750
# V25      -0.348379
# V26      -0.207864
# V27       0.454651
# V28       0.128932
# Amount   -1.199858
# Class    -0.850641
# dtype: float64

# %% [markdown]
# **z_scores**

# %%
z_scores = stats.zscore(filtered_data)  # Calculate z-scores for all numerical columns
z_scores_df = pd.DataFrame(z_scores, columns=filtered_data.columns, index=filtered_data.index)

print("\nZ-Scores:")
print(z_scores_df.head())
# Out:
# Z-Scores:
#          id        V1        V2        V3        V4        V5        V6  \
# 1 -1.447619  0.514214 -0.105066  0.112666  0.010747  0.164466  0.552213
# 4 -1.447599 -1.086164  0.420093  1.541162 -0.016650 -0.353429  0.777466
# 5 -1.447592 -0.774496  0.488273  1.045956 -0.398369  0.628865  0.619315
# 6 -1.447585  0.556351 -0.218308  0.023936  0.429956  0.327639  0.995536
# 9 -1.447565 -0.730030  0.617678  0.937060 -0.438340  0.736738  0.339580
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 1  0.080772 -0.122106  0.014321  ... -0.920630 -1.018215  0.616519 -0.636852
# 4  0.869583 -0.905885  1.228441  ... -0.234690  1.296489 -0.594698  0.329226
# 5  0.720188  0.276866 -0.273694  ... -0.864504 -0.901668 -0.036138 -0.695643
# 6  0.158272 -0.130868  0.789849  ... -0.735024 -0.465760 -0.677733 -1.418657
# 9  0.946393 -0.157146 -0.419571  ... -0.988470 -1.010970 -0.511400 -0.720859
#
# ...

# %%
import pandas as pd

class_distribution = balanced_data['Class'].value_counts()

print("Class Distribution in Filtered Data:")
print(class_distribution)

# You can also get the percentage distribution:
class_percentage = balanced_data['Class'].value_counts(normalize=True) * 100
print("\nClass Percentage Distribution in Filtered Data:")
print(class_percentage)
# Out:
# Class Distribution in Filtered Data:
# Class
# 0    181062
# 1    181062
# Name: count, dtype: int64
#
# Class Percentage Distribution in Filtered Data:
# Class
# 0    50.0
# 1    50.0
# Name: proportion, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = balanced_data.drop('Class', axis=1)
y = balanced_data['Class']

# Split data into training and testing sets (e.g., 80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 100)  # Adjust test_size and random_state as needed

# Print the shapes of the resulting sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (289699, 30)
# X_test shape: (72425, 30)

# %%
import pandas as pd

# Assuming y_train is a pandas Series or a numpy array
y_train_df = pd.DataFrame(y_train, columns=['Class'])  # Convert to DataFrame if needed

class_distribution = y_train_df['Class'].value_counts()

print("Class Distribution in Training Data:")
print(class_distribution)

# You can also get the percentage distribution:
class_percentage = y_train_df['Class'].value_counts(normalize=True) * 100
print("\nClass Percentage Distribution in Training Data:")
print(class_percentage)
# Out:
# Class Distribution in Training Data:
# Class
# 1    144904
# 0    144795
# Name: count, dtype: int64
#
# Class Percentage Distribution in Training Data:
# Class
# 1    50.018813
# 0    49.981187
# Name: proportion, dtype: float64

# %%
import pandas as pd

# Assuming y_test is a pandas Series or a numpy array
y_test_df = pd.DataFrame(y_test, columns=['Class'])  # Convert to DataFrame if needed

class_distribution = y_test_df['Class'].value_counts()

print("Class Distribution in Testing Data:")
print(class_distribution)

# You can also get the percentage distribution:
class_percentage = y_test_df['Class'].value_counts(normalize=True) * 100
print("\nClass Percentage Distribution in Testing Data:")
print(class_percentage)
# Out:
# Class Distribution in Testing Data:
# Class
# 0    36267
# 1    36158
# Name: count, dtype: int64
#
# Class Percentage Distribution in Testing Data:
# Class
# 0    50.07525
# 1    49.92475
# Name: proportion, dtype: float64

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Create and train the model
model = LogisticRegression()
model.fit(X_train, y_train)

# ... (rest of your code for prediction and evaluation) ...
# Train the model
model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")

# Print classification report and confusion matrix
print("Classification Report:")
print(classification_report(y_test, y_pred))

print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.11/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have X_train, X_test, y_train, y_test from previous code

# Define models
models = {
    "Logistic Regression": LogisticRegression(max_iter = 1000),
    "Random Forest": RandomForestClassifier(),
    "SVM": SVC()
}

# Create dictionaries to store results
results = {}
confusion_matrices = {}
classification_reports = {}

# Train and evaluate models
for model_name, model in models.items():
    print(f"Training {model_name}...")
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Store results
    results[model_name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1
    }

    # Store confusion matrix and classification report
    confusion_matrices[model_name] = confusion_matrix(y_test, y_pred)
    classification_reports[model_name] = classification_report(y_test, y_pred)

# Create a DataFrame from results
results_df = pd.DataFrame.from_dict(results, orient='index')

# --- Visualization ---

# 1. Comparison Bar Graph
results_df.plot(kind='bar', figsize=(10, 6))
plt.title('Model Comparison')
plt.ylabel('Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 2. Confusion Matrices
for model_name, cm in confusion_matrices.items():
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=['Predicted 0', 'Predicted 1'],
                yticklabels=['Actual 0', 'Actual 1'])
    plt.title(f"Confusion Matrix - {model_name}")
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.show()

# 3. Classification Reports
for model_name, report in classification_reports.items():
    print(f"Classification Report - {model_name}:\n{report}\n")
# Out:
# Training Logistic Regression...
# Training Random Forest...
# Training SVM...
# Classification Report - Logistic Regression:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36267
#            1       1.00      1.00      1.00     36158
#
#     accuracy                           1.00     72425
#    macro avg       1.00      1.00      1.00     72425
# weighted avg       1.00      1.00      1.00     72425
#
#
# Classification Report - Random Forest:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     36267
#            1       1.00      1.00      1.00     36158
#
#     accuracy                           1.00     72425
#    macro avg       1.00      1.00      1.00     72425
# weighted avg       1.00      1.00      1.00     72425
#
#
# Classification Report - SVM:
#               precision    recall  f1-score   support
#
# ...

# %%
# 3. Classification Reports with Accuracy
for model_name, report in classification_reports.items():

    print(f"Accuracy - {model_name}: {results[model_name]['Accuracy']:.10f}\n")
# Out:
# Accuracy - Logistic Regression: 0.9988125647
#
# Accuracy - Random Forest: 0.9998205040
#
# Accuracy - SVM: 0.9992544011

# %%
0.0# --- Statistical Tests ---

# Z-test for train and test accuracy
def z_test(p1, p2, n1, n2):
    p_combined = (p1 * n1 + p2 * n2) / (n1 + n2)
    standard_error = np.sqrt(p_combined * (1 - p_combined) * (1/n1 + 1/n2))
    z_score = (p1 - p2) / standard_error
    p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test
    return z_score, p_value

for model_name in models:
    train_samples = len(X_train)
    test_samples = len(X_test)
    train_accuracy = accuracy_score(y_train, models[model_name].predict(X_train))
    test_accuracy = results[model_name]['Accuracy']
    z_score, p_value = z_test(train_accuracy, test_accuracy, train_samples, test_samples)
    print(f"Z-test for {model_name}: Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
    if p_value < 0.05:
        print("Significant difference between train and test accuracy (p < 0.05). Model may be overfitting.")
    else:
        print("No significant difference between train and test accuracy.")

    # Cross-validation for t-test and ANOVA
    cv_scores = cross_val_score(models[model_name], X_train, y_train, cv=5)
    # T-test (comparing cross-validation scores to test accuracy)
    t_stat, t_p_value = ttest_ind(cv_scores, [test_accuracy] * 5)
    print(f"T-test for {model_name}: T-statistic: {t_stat:.4f}, P-value: {t_p_value:.4f}")

# ANOVA (comparing accuracy across models using cross-validation scores)
all_cv_scores = [cross_val_score(model, X_train, y_train, cv=5) for model in models.values()]
anova_stat, anova_p_value = f_oneway(*all_cv_scores)
print(f"ANOVA: F-statistic: {anova_stat:.4f}, P-value: {anova_p_value:.4f}")
if anova_p_value < 0.05:
    print("Significant differences exist between model accuracies.")
else:
    print("No significant differences between model accuracies.")
# Out:
# Z-test for Logistic Regression: Z-score: -0.5864, P-value: 0.5576
# No significant difference between train and test accuracy.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# T-test for Logistic Regression: T-statistic: -1.5056, P-value: 0.1706
# Z-test for Random Forest: Z-score: 7.2112, P-value: 0.0000
# Significant difference between train and test accuracy (p < 0.05). Model may be overfitting.
# /usr/local/lib/python3.11/dist-packages/scipy/stats/_axis_nan_policy.py:573: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   res = hypotest_fun_out(*samples, **kwds)
# ...

# %%
from scipy.stats import ttest_ind
from scipy.stats import norm

# Z-test for train and test accuracy
def z_test(p1, p2, n1, n2):
    p_combined = (p1 * n1 + p2 * n2) / (n1 + n2)
    standard_error = np.sqrt(p_combined * (1 - p_combined) * (1/n1 + 1/n2))
    z_score = (p1 - p2) / standard_error
    p_value = 2 * (1 - norm.cdf(abs(z_score)))  # Two-tailed test
    return z_score, p_value

train_samples = len(X_train)
test_samples = len(X_test)
# Instead of using history, directly use the calculated accuracy
train_accuracy = accuracy_score(y_train, models["Logistic Regression"].predict(X_train)) # Calculate training accuracy
# Assuming 'accuracy' in Global Variables is test accuracy for Logistic Regression
test_accuracy = accuracy
z_score, p_value = z_test(train_accuracy, test_accuracy, train_samples, test_samples)
print(f"Z-score: {z_score:.4f}, P-value: {p_value:.4f}")
if p_value < 0.05:
    print("Significant difference between train and test accuracy (p < 0.05). Model may be overfitting.")
else:
    print("No significant difference between train and test accuracy.")

# For t-test and ANOVA, you'll need accuracy values for multiple epochs/iterations.
# Since scikit-learn models don't provide this directly, consider using cross-validation.
# Example using cross_val_score for Logistic Regression:
from sklearn.model_selection import cross_val_score
cv_scores = cross_val_score(models["Logistic Regression"], X_train, y_train, cv=5)  # 5-fold cross-validation
# ... (rest of your code for t-test and ANOVA using cv_scores) ...

# Note: You can replace "Logistic Regression" with other model names in 'models' for t-test and ANOVA
# For ANOVA, you'd need accuracy scores for multiple models in a comparable way (e.g., cross-validation scores)
